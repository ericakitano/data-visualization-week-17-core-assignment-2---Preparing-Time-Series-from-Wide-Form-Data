# %% [markdown]
# # Import Library

# %%
import pandas as pd

# %% [markdown]
# # **Part 1**

# %% [markdown]
# ## Load Data

# %%
filename = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQN3Ksa9szQuO4G1-msXWAp17KtVHQCBnuEieu_auu1wSiBf3-krHusIx5VBMkihxj-KZLBosDIGEyR/pub?output=csv'
df = pd.read_csv(filename)
df.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
# 4      6915         4  San Antonio       city        TX    TX
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    253690.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    234181.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County    109068.0
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County    166139.0
# 4          San Antonio-New Braunfels, TX        Bexar County    114794.0
#
#    2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    255517.0  ...    741586.0    745686.0    750578.0    756734.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22467 entries, 0 to 22466
# Columns: 281 entries, RegionID to 2022-09-30
# dtypes: float64(273), int64(2), object(6)
# memory usage: 48.2+ MB

# %% [markdown]
# ## Filter the 4 largest cities into a new dataframe

# %%
#create a copy of the dataframe
df2 = df.copy()

# %%
#create filter
large_cities_filter = (df2['SizeRank'] >= 0) & (df2['SizeRank'] <=3)

# %%
#check filter
df2[large_cities_filter]
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    253690.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    234181.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County    109068.0
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County    166139.0
#
#    2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    255517.0  ...    741586.0    745686.0    750578.0    756734.0
# 1    234401.0  ...    924019.0    928991.0    937936.0    953874.0
# 2    109079.0  ...    245783.0    248718.0    252080.0    256435.0
# ...

# %%
#apply filter
df2 = df2[large_cities_filter]

# %%
df2.head(10)
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
#
#                                    Metro          CountyName  2000-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County    253690.0
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County    234181.0
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County    109068.0
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County    166139.0
#
#    2000-02-29  ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# 0    255517.0  ...    741586.0    745686.0    750578.0    756734.0
# 1    234401.0  ...    924019.0    928991.0    937936.0    953874.0
# 2    109079.0  ...    245783.0    248718.0    252080.0    256435.0
# ...

# %% [markdown]
# ## Melt the data to long-form and prepare it for time series analysis

# %%
df2.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'Metro', 'CountyName', '2000-01-31', '2000-02-29',
#        ...
#        '2021-12-31', '2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#        '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31', '2022-09-30'],
#       dtype='object', length=281)

# %%
melted = pd.melt(df2.drop(columns=['RegionID','StateName']),
                 id_vars=['SizeRank', 'RegionName','RegionType','State','Metro','CountyName'],
                value_name='Home Value',var_name="Date")
melted
# Out:
#       SizeRank   RegionName RegionType State  \
# 0            0     New York       city    NY
# 1            1  Los Angeles       city    CA
# 2            2      Houston       city    TX
# 3            3      Chicago       city    IL
# 4            0     New York       city    NY
# ...        ...          ...        ...   ...
# 1087         3      Chicago       city    IL
# 1088         0     New York       city    NY
# 1089         1  Los Angeles       city    CA
# 1090         2      Houston       city    TX
# 1091         3      Chicago       city    IL
#
#                                       Metro          CountyName        Date  \
# 0     New York-Newark-Jersey City, NY-NJ-PA       Queens County  2000-01-31
# 1        Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  2000-01-31
# 2      Houston-The Woodlands-Sugar Land, TX       Harris County  2000-01-31
# 3        Chicago-Naperville-Elgin, IL-IN-WI         Cook County  2000-01-31
# ...

# %% [markdown]
# ### Convert the melted dates into datetime datatype.

# %%
melted['Date'] = pd.to_datetime(melted['Date'])
melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092 entries, 0 to 1091
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SizeRank    1092 non-null   int64
#  1   RegionName  1092 non-null   object
#  2   RegionType  1092 non-null   object
#  3   State       1092 non-null   object
#  4   Metro       1092 non-null   object
#  5   CountyName  1092 non-null   object
#  6   Date        1092 non-null   datetime64[ns]
#  7   Home Value  1087 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 68.4+ KB

# %% [markdown]
# ### Make the datetime column the index.

# %%
melted = melted.set_index("Date")
melted
# Out:
#             SizeRank   RegionName RegionType State  \
# Date
# 2000-01-31         0     New York       city    NY
# 2000-01-31         1  Los Angeles       city    CA
# 2000-01-31         2      Houston       city    TX
# 2000-01-31         3      Chicago       city    IL
# 2000-02-29         0     New York       city    NY
# ...              ...          ...        ...   ...
# 2022-08-31         3      Chicago       city    IL
# 2022-09-30         0     New York       city    NY
# 2022-09-30         1  Los Angeles       city    CA
# 2022-09-30         2      Houston       city    TX
# 2022-09-30         3      Chicago       city    IL
#
#                                             Metro          CountyName  \
# Date
# 2000-01-31  New York-Newark-Jersey City, NY-NJ-PA       Queens County
# 2000-01-31     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County
# 2000-01-31   Houston-The Woodlands-Sugar Land, TX       Harris County
# ...

# %% [markdown]
# ## Resample the dataframe as monthly frequency, grouped by City.

# %%
df2_ts = melted.groupby('RegionName').resample("M").sum()
df2_ts
# Out:
# /var/folders/x3/rmq4ytz106933wm3zj2c9hyw0000gn/T/ipykernel_59133/1115457381.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2_ts = melted.groupby('RegionName').resample("M").sum()
# /var/folders/x3/rmq4ytz106933wm3zj2c9hyw0000gn/T/ipykernel_59133/1115457381.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2_ts = melted.groupby('RegionName').resample("M").sum()
# ...

# %% [markdown]
# # **Part 2**

# %%
cities = ['New York','Los Angeles','Houston', 'Chicago']
plot_df = df2_ts.loc[cities].copy()
plot_df
# Out:
#                        SizeRank  Home Value
# RegionName Date
# New York   2000-01-31         0    253690.0
#            2000-02-29         0    255517.0
#            2000-03-31         0    257207.0
#            2000-04-30         0    260310.0
#            2000-05-31         0    263204.0
# ...                         ...         ...
# Chicago    2022-05-31         3    312487.0
#            2022-06-30         3    314663.0
#            2022-07-31         3    315910.0
#            2022-08-31         3    315587.0
#            2022-09-30         3    315429.0
#
# [1092 rows x 2 columns]

# %%
plot_df = plot_df.drop(columns='SizeRank')
plot_df
# Out:
#                        Home Value
# RegionName Date
# New York   2000-01-31    253690.0
#            2000-02-29    255517.0
#            2000-03-31    257207.0
#            2000-04-30    260310.0
#            2000-05-31    263204.0
# ...                           ...
# Chicago    2022-05-31    312487.0
#            2022-06-30    314663.0
#            2022-07-31    315910.0
#            2022-08-31    315587.0
#            2022-09-30    315429.0
#
# [1092 rows x 1 columns]

# %%
unstacked = plot_df.unstack(level=0)
unstacked
# Out:
#            Home Value
# RegionName    Chicago   Houston Los Angeles  New York
# Date
# 2000-01-31   166139.0  109068.0    234181.0  253690.0
# 2000-02-29   166536.0  109079.0    234401.0  255517.0
# 2000-03-31   167368.0  108878.0    235513.0  257207.0
# 2000-04-30   168826.0  108881.0    237589.0  260310.0
# 2000-05-31   170499.0  108834.0    240113.0  263204.0
# ...               ...       ...         ...       ...
# 2022-05-31   312487.0  265558.0    990391.0  768797.0
# 2022-06-30   314663.0  268901.0    992337.0  773944.0
# 2022-07-31   315910.0  271059.0    992630.0  777692.0
# 2022-08-31   315587.0  272400.0    978196.0  779960.0
# 2022-09-30   315429.0  272639.0    966595.0  781622.0
#
# [273 rows x 4 columns]

# %%
ax = unstacked['Home Value'].plot()
ax.set_title('Home Value for 4 largest cities between 2000 - 2022')
ax.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# ## Reformat the y-axis ticks to use thousands of dollars with a "K" at the end. (e.g. "200K, 400K, etc")

# %% [markdown]
# Use Custom Function from Course 1 - Week 4 - Lecture 2 Code Along - Explanatory Visualization

# %%
from matplotlib.ticker import FuncFormatter

def thousands(y, pos):
    """function for use wth matplotlib FuncFormatter -  formats money in thousands"""
    return f"${y*1e-3: .0f}K"

# %%
# Create the formatter
price_K =FuncFormatter(thousands)

# %%
ax = unstacked['Home Value'].plot()
ax.set_title('Home Value for 4 largest cities between 2000 - 2022')
ax.set_xlabel('Date')
ax.set_ylabel ('Home Value (K)')
ax.yaxis.set_major_formatter(price_K)

# %% [markdown]
# ## **1) Which City had the highest Typical Home Value at the end of 2008? Which had the least?**

# %%
unstacked.head()
# Out:
#            Home Value
# RegionName    Chicago   Houston Los Angeles  New York
# Date
# 2000-01-31   166139.0  109068.0    234181.0  253690.0
# 2000-02-29   166536.0  109079.0    234401.0  255517.0
# 2000-03-31   167368.0  108878.0    235513.0  257207.0
# 2000-04-30   168826.0  108881.0    237589.0  260310.0
# 2000-05-31   170499.0  108834.0    240113.0  263204.0

# %%
unstacked[unstacked.index == '2008-12-31']
# Out:
#            Home Value
# RegionName    Chicago   Houston Los Angeles  New York
# Date
# 2008-12-31   265306.0  131283.0    469294.0  510309.0

# %% [markdown]
# **Answer**:
# - **New York** had the **highest** typical Home Value at the end of 2008.
# - **Houston** had the **least** typical Home Value at the end of 2008.

# %% [markdown]
# ## 2) How much did the home values change from November 2008 to December 2008 (in dollars)?

# %%
#unstacked[unstacked.index == '2008-11-30']
# Out:
#            Home Value
# RegionName    Chicago   Houston Los Angeles  New York
# Date
# 2008-11-30   271059.0  132247.0    481905.0  514767.0

# %%
#unstacked[unstacked.index == '2008-12-31']
# Out:
#            Home Value
# RegionName    Chicago   Houston Los Angeles  New York
# Date
# 2008-12-31   265306.0  131283.0    469294.0  510309.0

# %%
#unstacked.diff(periods=1)
# Out:
#            Home Value
# RegionName    Chicago Houston Los Angeles New York
# Date
# 2000-01-31        NaN     NaN         NaN      NaN
# 2000-02-29      397.0    11.0       220.0   1827.0
# 2000-03-31      832.0  -201.0      1112.0   1690.0
# 2000-04-30     1458.0     3.0      2076.0   3103.0
# 2000-05-31     1673.0   -47.0      2524.0   2894.0
# ...               ...     ...         ...      ...
# 2022-05-31     2838.0  4457.0     17223.0   6476.0
# 2022-06-30     2176.0  3343.0      1946.0   5147.0
# 2022-07-31     1247.0  2158.0       293.0   3748.0
# 2022-08-31     -323.0  1341.0    -14434.0   2268.0
# 2022-09-30     -158.0   239.0    -11601.0   1662.0
#
# [273 rows x 4 columns]

# %%
diff_df = unstacked.diff(periods=1)

# %%
diff_df[diff_df.index == '2008-12-31']
# Out:
#            Home Value
# RegionName    Chicago Houston Los Angeles New York
# Date
# 2008-12-31    -5753.0  -964.0    -12611.0  -4458.0

# %% [markdown]
# **Answer**:
#
# Home Values changed by:
#
# - -5753 Dollars in Chicago
# - -964 Dollars in Houston
# - -12611 Dollars in LA
# - -4458 Dollars in NY
